# %%
print("hey this is ajay")
# Out:
# hey this is ajay

# %%
a=50
print(a)
# Out:
# 50

# %%
#logical
#and , or ,not

# %%
#Server Monitoring
server_down = True
backup_active = False
if server_down and not backup_active:   #both true
     print("Critical Warning")
# Out:
# Critical Warning

# %%
#bitwise
a=5
b=2
print(a&b)
print(a|b)
print(a^b)
# Out:
# 0
# 7
# 7

# %%
print(22//4)
print(22>>2)
# Out:
# 5
# 5

# %% [markdown]
# Identiy opertaer

# %%
a=10
b=10
print(a is b)
print(a is not b)
a=[1,2,3]
b=[1,2,3]
print(a is b)
print(a is not b)
# Out:
# True
# False
# False
# True

# %%
n=-5
n2=-5
print(n==n2)
print(n is n2)
print(id(n))
print(id(n2))
# Out:
# True
# True
# 11645160
# 11645160

# %%
#-5 to 256
n=-6
n2=-6
print(n==n2)
print(n is n2)
print(id(n))
print(id(n2))
# Out:
# True
# False
# 133898474388112
# 133898474386768

# %% [markdown]
# Conditional statement

# %%
num1=10
num2=20
if num1<num2 :
  print("num 2 is greater",num2)
# Out:
# num 2 is greater 20

# %%
num1=int(input("Enter the number"))
if num1:
  print("num1 exist i.e. = ",num1)
else:
  print("num1 is zero",num1)
# Out:
# Enter the number22
# num1 exist i.e. =  22

# %%
#if,elif,else
age = int(input("Enter the number: "))
if age == 18:
     print("your age is: ",age)
elif age > 18 :
      print("your age is greater than 18 -: ", age)
else:
     print("your age is less than 18 -:",age)
# Out:
# Enter the number: 19
# your age is greater than :  19

# %%
marks =int(input("enter marks : "))
if marks >=95 and marks<101:
    print("grade is A")
elif marks>=75:
    print("grade is B")
elif marks>=60:
    print("grade is c")
else:
    print("fail")
# Out:
# enter marks76
# grade is B

# %% [markdown]
# LOOP
# for

# %%
for i in range(7):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
l=[1,2,34,4]
for i in l:
  print(i)
# Out:
# 1
# 2
# 34
# 4

# %%
l=[1,2,34,4]
for i in range(len(l)):
  print(l[i])
# Out:
# 1
# 2
# 34
# 4

# %% [markdown]
# While

# %%
l=[10,11,12,13,14,15]
i=0
while i<len(l):
  print(l[i])
  i+=1
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
#example for loop
d={"name":"hello","age":20,"phone_no":"002032"}
l=d.keys().  #v = d.values()
for i in l:
  print(i)
  print(d[i])
# Out:
# name
# hello
# age
# 20
# phone_no
# 002032

# %%
l=[10,[11,12,13,14,15]]
for i in l[1]:         #for i in range(len(l[1])):
                       #print(l[1][i])
  print(i)
# Out:
# 11
# 12
# 13
# 14

# %% [markdown]
# KEYWORDS

# %%
#break
for i in range(5):
  if(i==2):
    break
  print(i)

#break & continue
i=0
while True:
  print(i)
  if i==5:
    break
  else:
    i+=1
    continue
print("out of loop while")
#pass -- > kuch nhi likha then also pass
i=0
while True:
  print(i)
  if i==4:
    pass
  if i==5:
    break

  else:
    i+=1
    continue
# Out:
# 0
# 1
# 0
# 1
# 2
# 3
# 4
# 5
# out of loop while
# 0
# 1
# 2
# 3
# 4
# 5
